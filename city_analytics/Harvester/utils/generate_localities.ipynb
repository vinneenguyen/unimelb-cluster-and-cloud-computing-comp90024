# %% [markdown]
# # Setup

# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
from difflib import get_close_matches
from IPython.display import display

# Current working directory
# %cd /content/drive/My Drive/unimelb-cluster-and-cloud-computing-comp90024-2020-sm1/city_analytics/geospatial

# Global constants
DATADIR = Path("../geodata")
POSTCODE_FILE = Path(DATADIR/"australian_postcodes.csv")
LOCALITY_FILE = DATADIR / "localities.csv"  # source statistical areas (SAs)
CITYFILE_TEST = DATADIR / "city_names_test.json"  # city names to map to SAs
# Out:
# /content/drive/My Drive/unimelb-cluster-and-cloud-computing-comp90024-2020-sm1/city_analytics/geospatial

# %% [markdown]
# # Create source SAs from postal areas
# See references for download link of original file.

# %%
# Original data
data_postcode = pd.read_csv(DATAFILE_POSTCODE, dtype={"sa3": "Int64", "sa4": "Int64"},
                            converters={"locality": str.lower, "state": str.lower})
data_postcode.dropna(subset=["sa3", "sa4"], inplace=True)  # clear NAs
data_postcode.drop_duplicates(subset=["locality", "state"], keep="last", inplace=True, ignore_index=True)

# Augmented data
duplicated = data_postcode.duplicated(subset="locality", keep=False)  # same locality, different state
data_postcode["locality_mixed"] = data_postcode.locality + duplicated*(" "+data_postcode.state)  # combine locality and state into mixed name for duplicated
display(data_postcode[duplicated].sort_values("locality"))
data_postcode.to_csv(LOCALITY_FILE, index=False)
# Out:
#           id  postcode  ... region   locality_mixed
# 482     4586      2046  ...     R1   abbotsford nsw
# 5686    4625      3067  ...     R1   abbotsford vic
# 11086  12626      4670  ...     R3   abbotsford qld
# 1553    3151      2336  ...     R3     aberdeen nsw
# 16906  11359      7310  ...     R3     aberdeen tas
# ...      ...       ...  ...    ...              ...
# 7199    7822      3505  ...     R3        yelta vic
# 4365    3702      2681  ...     R3        yenda nsw
# 10917  13026      4625  ...     R3        yenda qld
# 16468  10043      7120  ...     R3  york plains tas
# 7081      36      3477  ...     R3  york plains vic
#
# [2266 rows x 15 columns]

# %% [markdown]
# # Map city names to SA codes

# %%
# City names
with open(CITYFILE_TEST) as f:
  citynames = list(map(str.lower, json.load(f)))
print(citynames)

# Source SA codes
data_locality = pd.read_csv(LOCALITY_FILE, dtype={"sa3": "Int64", "sa4": "Int64"})
codes = dict(zip(map(str.lower, data_locality.locality_mixed), data_locality.sa4))  # using SA4
print(codes)

def locality_to_sa4(locality, cutoff=0.6):
  """
  Map locality to code of statistical area level 4
  locality: city/suburb name
  cutoff: minimum match ratio to approve similar locality
  """

  locality = locality.lower()

  # Exact mapping
  if locality in codes:
    return codes[locality]
  
  # Approx. mapping
  matches = get_close_matches(locality, codes, n=1, cutoff=cutoff)
  if matches:
    [m] = matches  # best matched locality
    return codes[m]

  return 0

print(locality_to_sa4("melbourn"))  # exact map
print(locality_to_sa4("gold coast"))  # approx. map
# Out:
# ['aberdeen', 'adaminaby', 'adelaide', 'adelaide river', 'adelong', 'agnes water', 'aireys inlet - fairhaven', 'airlie beach - cannonvale', 'albany', 'albury', 'aldinga', 'alexandra', 'alice river', 'alice springs', 'allansford', 'allendale east', 'alligator creek', 'allora', 'alstonville', 'alyangula', 'amata', 'american river', 'amity point', 'angaston', 'angle vale', 'anglesea', 'anna bay', 'apollo bay', 'appin', 'ararat', 'aratula', 'arcadia bay', 'arcadia downs', 'ardlethan', 'ardrossan', 'armidale', 'armstrong beach', 'arrawarra', 'arthurs seat', 'ashley', 'atherton', 'auburn', 'augathella', 'augusta', 'avenel', 'avoca', 'awaba', 'axedale', 'ayr', 'babinda', 'bacchus marsh', 'bagdad', 'bairnsdale', 'bakers hill', 'balaklava', 'baldivis', 'balgal beach', 'balhannah', 'balingup', 'ballan', 'ballarat', 'ballina', 'balnarring - balnarring beach', 'balranald', 'bangalow', 'bannockburn', 'barcaldine', 'barellan', 'bargara - innes park', 'bargo', 'barham', 'barmera', 'barnawartha', 'barooga', 'basin view', 'batchelor', 'batemans bay', 'batesford', 'bathurst', 'batlow', 'baw baw village', 'bawley point', 'beachmere', 'beachport', 'beaconsfield', 'beaconsfield upper', 'beaudesert', 'beaufort', 'beauty point', 'beechmont', 'beechwood', 'beechworth', 'beerburrum', 'beerburrum - north', 'beerwah', 'bega', 'belimbla park', 'bellingen', 'benalla', 'benaraby', 'bendigo', 'bermagui', 'berrara - cudmirrah', 'berri', 'berridale', 'berrigan', 'berrima', 'berry', 'beulah', 'beverley', 'bicheno', 'bickley', 'bidyadanga (lagrange)', 'biloela', 'binalong bay', 'bingara', 'binningup', 'birchip', 'birdwood', 'birregurra', 'black mountain', 'blackall', 'blackheath', 'blackwater', 'blackwood', 'blanchetown', 'blayney', 'blind bight', 'blue mountains', 'bluewater', 'blyth', 'boat harbour', 'bodalla', 'boddington - ranford', 'boggabilla', 'boggabri', 'bombala', 'bonalbo', 'bongaree - woorim', 'bonny hills', 'bonville - east', 'booleroo centre', 'boomerang beach - blueys beach', 'boonah', 'boort', 'bordertown', 'boreen point', 'borroloola', 'boston', 'bourke', 'bowen', 'bowen mountain', 'bowning', 'bowral - mittagong', 'boyanup', 'boyland', 'boyup brook', 'braidwood', 'branxton', 'bremer bay', 'brewarrina', 'briagolong', 'bridgetown', 'bridgewater', 'bridport', 'bright', 'brisbane', 'broadford', 'broadwater', 'broke', 'broken hill', 'brooklyn', 'brookton', 'broome', 'broulee - mossy point', 'bruce rock', 'brunswick heads', 'bulahdelah', 'bulla', 'bullsbrook', 'buln buln', 'bunbury', 'bundaberg', 'bundalong', 'bundanoon', 'bundeena', 'bungendore', 'bunyip', 'burketown', 'burnett heads', 'burnie - somerset', 'buronga', 'burra', 'burrawang', 'burrum heads', 'burrum heads - east', 'bushfield - woodford', 'busselton', 'buxton', 'byron bay', 'cabbage tree point', 'cairns', 'callala bay', 'calliope', 'cambewarra village', 'cambooya', 'camden haven', 'camooweal', 'campbell town', 'camperdown', 'canberra', 'cannons creek', 'canowindra', 'canungra', 'cape burney', 'cape paterson', 'cape schanck', 'cape woolamai', 'capel', 'captains flat', 'carcoar', 'cardwell', 'carisbrook', 'carnamah', 'carnarvon', 'carrick', 'carrickalinga', 'casino', 'casterton', 'castlemaine', 'catherine field', 'cedar grove', 'cedar vale', 'ceduna', 'central coast', 'cervantes', 'cessnock', 'charleston', 'charleville', 'charlton', 'charters towers', 'cherbourg', 'childers', 'chiltern', 'chinchilla', 'churchill', 'clare', 'clarendon', 'clarenza', 'clayton bay', 'clermont', 'cleve', 'clifton beach', 'clunes (vic.)', 'clyde', 'cobar', 'cobargo', 'cobbitty', 'cobden', 'cobdogla', 'cobram', 'cockatoo valley', 'coconuts', 'coen', 'coffin bay', 'coffs harbour', 'cohuna', 'colac', 'coleambally', 'collie', 'collinsvale', 'collinsville', 'colo vale', 'condobolin', 'conjola park', 'coober pedy', 'coobowie', 'coochiemudlo island', 'cooktown', 'coolah', 'coolamon', 'coolgardie', 'cooloola village', 'cooma', 'coomba park', 'coonabarabran', 'coonalpyn', 'coonamble', 'cooran', 'cooroibah', 'cooroy', 'coot ...
# {'darwin': 701, 'alawa': 701, 'brinkin': 701, 'coconut grove': 701, 'jingili': 701, 'lee point': 701, 'lyons nt': 701, 'millner': 701, 'moil': 701, 'muirhead': 701, 'nakara': 701, 'rapid creek': 701, 'tiwi': 701, 'wagaman': 701, 'wanguri': 701, 'casuarina nt': 701, 'anula': 701, 'buffalo creek nt': 701, 'holmes': 701, 'karama': 701, 'leanyer': 701, 'malak': 701, 'marrara': 701, 'northlakes': 701, 'woodleigh gardens': 701, 'wulagi': 701, 'sanderson': 701, 'nightcliff': 701, 'bagot': 701, 'bayview nt': 701, 'coonawarra nt': 701, 'cullen bay': 701, 'darwin dc': 701, 'darwin international airport': 701, 'east point': 701, 'eaton nt': 701, 'fannie bay': 701, 'larrakeyah': 701, 'ludmilla': 701, 'parap': 701, 'raaf base darwin': 701, 'stuart park': 701, 'the gardens nt': 701, 'the narrows nt': 701, 'woolner': 701, 'acacia hills nt': 702, 'angurugu': 702, 'anindilyakwa': 702, 'annie river': 702, 'bathurst island': 702, 'bees creek': 702, 'belyuen': 702, 'black jungle': 702, 'blackmore': 702, 'border store': 702, 'burrundie': 702, 'bynoe': 702, 'bynoe harbour': 702, 'camp creek nt': 702, 'channel island': 702, 'charles darwin': 702, 'charlotte': 702, 'claravale': 702, 'cobourg': 702, 'collett creek': 702, 'coomalie creek': 702, 'cox peninsula': 702, 'croker island': 702, 'daly river': 702, 'darwin mc': 702, 'darwin river dam': 702, 'delissaville': 702, 'douglas-daly': 702, 'east arm': 702, 'east arnhem': 702, 'elrundie': 702, 'eva valley': 702, 'finniss valley': 702, 'fly creek': 702, 'freds pass': 702, 'galiwinku': 702, 'glyde point': 702, 'goulbourn island': 702, 'goulburn island': 702, 'gunbalanya': 702, 'gunn point': 702, 'hayes creek': 702, 'hidden valley nt': 702, 'hotham': 702, 'hughes nt': 702, 'kakadu': 702, 'koolpinyah': 702, 'lake bennett': 702, 'lambells lagoon': 702, 'litchfield park': 702, 'livingstone': 702, 'lloyd creek': 702, 'mandorah': 702, 'maningrida': 702, 'maranunga': 702, 'margaret river nt': 702, 'mcminns lagoon': 702, 'mickett creek': 702, 'middle point': 702, 'milingimbi': 702, 'millwood nt': 702, 'milyakburra': 702, 'minjilang': 702, 'mount bundey': 702, 'murrumujuk': 702, 'nauiyu': 702, 'nemarluk': 702, 'nganmarriyanga': 702, 'nguiu': 702, 'numburindi': 702, 'oenpelli': 702, 'peppimenarti': 702, 'pirlangimpi': 702, 'point stephens': 702, 'point stuart': 702, 'pularumpi': 702, 'pulumpa': 702, 'rakula': 702, 'ramingining': 702, 'robin falls': 702, 'rum jungle': 702, 'sandpalms roadhouse': 702, 'southport nt': 702, 'stapleton': 702, 'thamarrurr': 702, 'tipperary nt': 702, 'tivendale': 702, 'tiwi islands': 702, 'tortilla flats': 702, 'tumbling waters': 702, 'umbakumba': 702, 'vernon islands': 702, 'wadeye': 702, 'wagait beach': 702, 'wak wak': 702, 'warruwi': 702, 'weddell': 702, 'west arnhem': 702, 'wickham nt': 702, 'wishart nt': 702, 'woolaning': 702, 'wurrumiyanga': 702, 'berrimah': 701, 'knuckey lagoon': 701, 'pinelands nt': 701, 'archer': 701, 'driver': 701, 'durack nt': 701, 'farrar': 701, 'gray nt': 701, 'marlow lagoon': 701, 'moulden': 701, 'shoal bay nt': 701, 'woodroffe': 701, 'yarrawonga nt': 701, 'palmerston nt': 701, 'bakewell': 701, 'bellamack': 701, 'gunn': 701, 'johnston': 701, 'mitchell nt': 701, 'rosebery nt': 701, 'rosebery heights': 701, 'zuccoli': 701, 'howard springs': 701, 'virginia nt': 701, 'herbert': 701, 'humpty doo': 701, 'manton nt': 701, 'noonamah': 701, 'berry springs': 701, 'coolalinga': 701, 'dundee beach': 702, 'dundee downs': 702, 'dundee forest': 702, 'darwin river': 701, 'batchelor': 702, 'adelaide river': 702, 'pine creek nt': 702, 'cossack nt': 702, 'emungalan': 702, 'katherine east': 702, 'katherine south': 702, 'lansdowne nt': 702, 'arnold nt': 702, 'baines': 702, 'barunga': 702, 'beswick': 702, 'beswick creek': 702, 'binjari': 702, 'birdum': 702, 'bradshaw': 702, 'buchanan nt': 702, 'bulman weemol': 702, 'creswell': 702, 'daguragu': 702, 'daly waters': 702, 'delamere nt': 702, 'dunmarra': 702, 'edith nt': 702, 'edith river': 702, 'elsey': 702, 'elsey station': 702, 'fl ...
# 206
# 309

# %% [markdown]
# # References
# Urban centers and localities
# https://www.abs.gov.au/AUSSTATS/abs@.nsf/DetailsPage/1270.0.55.004July%202016?OpenDocument
#
# Postal codes including SA3, SA4
# https://www.matthewproctor.com/australian_postcodes
