# %% [markdown]
# # Set up
# [MPI for Python](https://mpi4py.readthedocs.io/en/stable/install.html#using-pip-or-easy-install)

# %%
#!pip install mpi4py # MPI for Python

from google.colab import drive
import os
import json
from collections import Counter
import re
from pprint import pprint

# Mount Drive before changing working directory
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/unimelb-cluster-and-cloud-computing-comp90024-2020-sm1/twitter_hashtags"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/unimelb-cluster-and-cloud-computing-comp90024-2020-sm1/twitter_hashtags

# %% [markdown]
# # Data

# %% [markdown]
# Each line of data file (except first line/last line) contains json text representing
# [Tweet Data Dictionary](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object), under field "doc".

# %%
datafile = "data/tinyTwitter.json"
with open(datafile) as f:
  lines = f.readlines()

print(lines[0]) # 1st line
print(lines[1]) # 2nd line
print(lines[-1]) # last line
# Out:
# {"total_rows":215443567,"offset":211386044,"rows":[
#
# {"id":"1212161512334336000","key":["sydney",2020,1,1],"value":1,"doc":{"_id":"1212161512334336000","_rev":"1-a51c37b5a85cf6a96735628afbea2c75","created_at":"Wed Jan 01 00:00:00 +0000 2020","id":1212161512334336000,"id_str":"1212161512334336000","text":"@La_Doine Pues ahora si, feliz 2020 🎊","truncated":false,"entities":{"hashtags":[],"symbols":[],"user_mentions":[{"screen_name":"La_Doine","name":"Star","id":320174862,"id_str":"320174862","indices":[0,9]}],"urls":[]},"metadata":{"iso_language_code":"es","result_type":"recent"},"source":"<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>","in_reply_to_status_id":1212157896512942000,"in_reply_to_status_id_str":"1212157896512942080","in_reply_to_user_id":320174862,"in_reply_to_user_id_str":"320174862","in_reply_to_screen_name":"La_Doine","user":{"id":1011510954406961200,"id_str":"1011510954406961153","name":"AySeñorQueNosComenLosMonguers","screen_name":"BocataJamonEHM","location":"Calle Wallaby 42 Sidney","description":"Intento de humorista fallido reconvertido en payaso de baja autoestima y gran corazón,no me muero de la pereza que me da.","url":null,"entities":{"description":{"urls":[]}},"protected":false,"followers_count":12245,"friends_count":144,"listed_count":43,"created_at":"Tue Jun 26 07:26:19 +0000 2018","favourites_count":59819,"utc_offset":null,"time_zone":null,"geo_enabled":false,"verified":false,"statuses_count":29587,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"F5F8FA","profile_background_image_url":null,"profile_background_image_url_https":null,"profile_background_tile":false,"profile_image_url":"http://pbs.twimg.com/profile_images/1011512550989721601/nK-Sajra_normal.jpg","profile_image_url_https":"https://pbs.twimg.com/profile_images/1011512550989721601/nK-Sajra_normal.jpg","profile_banner_url":"https://pbs.twimg.com/profile_banners/1011510954406961153/1529998634","profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":true,"default_profile":true,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"none"},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"favorited":false,"retweeted":false,"lang":"es","location":"sydney"}},
#
# {"id":"1212167199793614848","key":["sydney",2020,1,1],"value":1,"doc":{"_id":"1212167199793614848","_rev":"1-144bb7aa614168777f1a499c8dd6b892","created_at":"Wed Jan 01 00:22:36 +0000 2020","id":1212167199793614800,"id_str":"1212167199793614848","text":"RT @5SOS: Have an incredible new year. Thank you for an incredible decade of music, growth, happiness and challenges. \nHere’s to more music…","truncated":false,"entities":{"hashtags":[],"symbols":[],"user_mentions":[{"screen_name":"5SOS","name":"5 Seconds of Summer","id":264107729,"id_str":"264107729","indices":[3,8]}],"urls":[]},"metadata":{"iso_language_code":"en","result_type":"recent"},"source":"<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1061542997559394300,"id_str":"1061542997559394305","name":"ABC Rambo","screen_name":"abc_rambo","location":"","description":"","url":null,"entities":{"description":{"urls":[]}},"protected":false,"followers_count":64,"friends_count":486,"listed_count":0,"created_at":"Sun Nov 11 08:55:47 +0000 2018","favourites_count":45390,"utc_offset":null,"time_zone":null,"geo_enabled":false,"verified":false,"statuses_count":45483,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"F5F8FA","profile_background_image_url":null,"profile_background_image_url_https":null,"profile_background_tile":false,"profile_image_url":"http://pbs.twimg.com/profile_images/1061856433170313216/kvcT3lcB_normal.jpg","profile_image_url_https":"https://pbs.twimg.com/profile_images/1061856433170313216/kvcT3lcB_normal.jpg","profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":false,"default_profile":true,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"none"},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Tue Dec 31 20:12:25 +0000 2019","id":1212104239268290600,"id_str":"1212104239268290560","text":"Have an incredible new year. Thank you for an incredible decade of music, growth, happiness and challenges. \nHere’s… https://t.co/v0dqY2UOJD","truncated":true,"entities":{"hashtags":[],"symbols":[],"user_mentions":[],"urls":[{"url":"https://t.co/v0dqY2UOJD","expanded_url":"https://twitter.com/i/web/status/1212104239268290560","display_url":"twitter.com/i/web/status/1…","indices":[117,140]}]},"metadata":{"iso_language_code":"en","result_type":"recent"},"source":"<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":264107729,"id_str":"264107729","name":"5 Seconds of Summer","screen_name":"5SOS","location":"Sydney, Australia","description":"An Australian Band Called 5 Seconds Of Summer // TEETH // https://t.co/ExYCI8n0xI // @ashton5sos @calum5sos @michael5sos @luke5sos // email: hi@5sos.com","url":"https://t.co/Z3PbU8XeY2","entities":{"url":{"urls":[{"url":"https://t.co/Z3PbU8XeY2","expanded_url":"http://5sos.com","display_url":"5sos.com","indices":[0,23]}]},"description":{"urls":[{"url":"https://t.co/ExYCI8n0xI","expanded_url":"https://smarturl.it/Teeth5SOS","display_url":"smarturl.it/Teeth5SOS","indices":[58,81]}]}},"protected":false,"followers_count":12622502,"friends_count":29971,"listed_count":26553,"created_at":"Fri Mar 11 10:18:46 +0000 2011","favourites_count":5727,"utc_offset":null,"time_zone":null,"geo_enabled":true,"verified":true,"statuses_count":27844,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":true,"profile_ ...

# %% [markdown]
# # Process line (elementary workflow)

# %% [markdown]
# ## Remove unwanted characters
#
# As each line may end with characters (e.g ',' ']' '}') resulting in badly formatted json text, those trailing characters need to be removed.

# %%
def remove_trails(text):
  """
  Remove unwanted trailing characters from json text
  text: line of json text
  """

  text = text.rstrip() # remove trailing whitespace (\n)
  text = re.sub(r"(?<=}),?]?}?$", "", text) # remove unwanted trailing ',' ']' '}'

  return text

# Test
print(remove_trails('{"id":"1212","doc":{"_id":"1212"}},\n'))
assert remove_trails('{"id":"1212","doc":{"_id":"1212"}},\n') == '{"id":"1212","doc":{"_id":"1212"}}'
assert remove_trails('{"id":"1212","doc":{"_id":"1212"}}]}\n') == '{"id":"1212","doc":{"_id":"1212"}}'

# Real data
lines_clean = list(map(remove_trails, lines))
print(*lines_clean[:3], sep="\n")
# Out:
# {"id":"1212","doc":{"_id":"1212"}}
# {"total_rows":215443567,"offset":211386044,"rows":[
# {"id":"1212161512334336000","key":["sydney",2020,1,1],"value":1,"doc":{"_id":"1212161512334336000","_rev":"1-a51c37b5a85cf6a96735628afbea2c75","created_at":"Wed Jan 01 00:00:00 +0000 2020","id":1212161512334336000,"id_str":"1212161512334336000","text":"@La_Doine Pues ahora si, feliz 2020 🎊","truncated":false,"entities":{"hashtags":[],"symbols":[],"user_mentions":[{"screen_name":"La_Doine","name":"Star","id":320174862,"id_str":"320174862","indices":[0,9]}],"urls":[]},"metadata":{"iso_language_code":"es","result_type":"recent"},"source":"<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>","in_reply_to_status_id":1212157896512942000,"in_reply_to_status_id_str":"1212157896512942080","in_reply_to_user_id":320174862,"in_reply_to_user_id_str":"320174862","in_reply_to_screen_name":"La_Doine","user":{"id":1011510954406961200,"id_str":"1011510954406961153","name":"AySeñorQueNosComenLosMonguers","screen_name":"BocataJamonEHM","location":"Calle Wallaby 42 Sidney","description":"Intento de humorista fallido reconvertido en payaso de baja autoestima y gran corazón,no me muero de la pereza que me da.","url":null,"entities":{"description":{"urls":[]}},"protected":false,"followers_count":12245,"friends_count":144,"listed_count":43,"created_at":"Tue Jun 26 07:26:19 +0000 2018","favourites_count":59819,"utc_offset":null,"time_zone":null,"geo_enabled":false,"verified":false,"statuses_count":29587,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"F5F8FA","profile_background_image_url":null,"profile_background_image_url_https":null,"profile_background_tile":false,"profile_image_url":"http://pbs.twimg.com/profile_images/1011512550989721601/nK-Sajra_normal.jpg","profile_image_url_https":"https://pbs.twimg.com/profile_images/1011512550989721601/nK-Sajra_normal.jpg","profile_banner_url":"https://pbs.twimg.com/profile_banners/1011510954406961153/1529998634","profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":true,"default_profile":true,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"none"},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"favorited":false,"retweeted":false,"lang":"es","location":"sydney"}}
# {"id":"1212161512770437121","key":["sydney",2020,1,1],"value":1,"doc":{"_id":"1212161512770437121","_rev":"1-1f228a4dc2ba239e787ac0573945aee6","created_at":"Wed Jan 01 00:00:00 +0000 2020","id":1212161512770437000,"id_str":"1212161512770437121","text":"RT @gabriellecj: A prime minister who cannot or will not rise to the occasion - 'No better place to raise kids': Scott Morrison's new year…","truncated":false,"entities":{"hashtags":[],"symbols":[],"user_mentions":[{"screen_name":"gabriellecj","name":"Gabrielle Jackson","id":6814772,"id_str":"6814772","indices":[3,15]}],"urls":[]},"metadata":{"iso_language_code":"en","result_type":"recent"},"source":"<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":169804331,"id_str":"169804331","name":"michael inman","screen_name":"mickinman","location":"Canberra, Australia","description":"In depth producer/reporter. @abccanberra Ex-@canberratimes crime/court reporter","url":"https://t.co/N1HhZ13SSn","entities":{"url":{"urls":[{"url":"https://t.co/N1HhZ13SSn","expanded_url":"http://www.abc.net.au/canberra","display_url":"abc.net.au/canberra","indices":[0,23]}]},"description":{"urls":[]}},"protected":false,"followers_count":2730,"friends_count":5612,"listed_count":63,"created_at":"Fri Jul 23 05:48:59 +0000 2010","favourites_count":867,"utc_offset":null,"time_zone":null,"geo_enabled":false,"verified":true,"statuses_count":12846,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"C0DEED","profile_background_image_url":"http://abs.twimg.com/images/themes/theme1/bg.png","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme1/bg.png","profile_background_tile":true,"profile_image_url":"http://pbs.twimg.com/profile_images/1046381138548150272/sVCsRuDl_normal.jpg","profile_image_url_https":"https://pbs.twimg.com/profile_images/1046381138548150272/sVCsRuDl_normal.jpg","profile_banner_url":"https://pbs.twimg.com/profile_banners/169804331/1469162040","profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":false,"default_profile":false,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"none"},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Tue Dec 31 21:06:57 +0000 2019","id":1212117963165225000,"id_str":"1212117963165224960","text":"A prime minister who cannot or will not rise to the occasion - 'No better place to raise kids': Scott Morrison's ne… https://t.co/pTtEt0vGnv","truncated":true,"entities":{"hashtags":[],"symbols":[],"user_mentions":[],"urls":[{"url":"https://t.co/pTtEt0vGnv","expanded_url":"https://twitter.com/i/web/status/1212117963165224960","display_url":"twitter.com/i/web/status/1…","indices":[117,140]}]},"metadata":{"iso_language_code":"en","result_type":"recent"},"source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":6814772,"id_str":"6814772","name":"Gabrielle Jackson","screen_name":"gabriellecj","location":"Sydney, Australia","description":"Associate news editor for Guardian Australia. My book Pain and Prejudice is out now in Australia & NZ (Allen & Unwin) and UK (Little, Brown). Also in audiobook.","url":"https://t.co/McPGtnaNfX","entities":{"url":{"urls":[{"url":"https://t.co/McPGtnaNfX","expanded_url":"https://www.booktopia.com.au/pain-and-prejudice-gabrielle-jackson/prod9781760529093.html","display_url":"booktopia.com.au/pain-and-preju…" ...

# %% [markdown]
# ## Parse for Tweet Data Dictionary

# %%
def parse_tweet(text):
  """
  Parse for Tweet Data Dictionary in json text, under field "doc"
  text: line of json text
  """

  try:
    data = json.loads(text)
    tweet = data["doc"]
  except json.decoder.JSONDecodeError: # illegal text
    tweet = {} 

  return tweet

# Test
print(parse_tweet('{"id":"1212","doc":{"_id":"1212"}}'))
assert parse_tweet('{"id":"1212","doc":{"_id":"1212"}}') == {"_id":"1212"}
assert not parse_tweet('{"total_rows":215443567,"offset":211386044,"rows":[') # not any tweet data

# Real data
tweets = [t for t in map(parse_tweet, lines_clean) if t] # skip first line
pprint(tweets[-20:-10])
# Out:
# {'_id': '1212'}
# [{'_id': '1212167168650928128',
#   '_rev': '1-37f7c07370b3f01b8075a9a8d68ff9a4',
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 01 00:22:28 +0000 2020',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 557468072,
#                                   'id_str': '557468072',
#                                   'indices': [3, 17],
#                                   'name': 'Powerglobal',
#                                   'screen_name': 'powerglobalus'},
#                                  {'id': 1032904812281520100,
#                                   'id_str': '1032904812281520128',
#                                   'indices': [19, 35],
#                                   'name': 'SylviaD',
#                                   'screen_name': 'SylviaD32911201'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1212167168650928000,
#   'id_str': '1212167168650928128',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'location': 'sydney',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Wed Jan 01 00:21:08 +0000 2020',
#                        'entities': {'hashtags': [],
#                                     'symbols': [],
#                                     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                               'expanded_url': 'https://twitter.com/i/web/status/1212166834197106688',
#                                               'indices': [116, 139],
#                                               'url': 'https://t.co/BaM0MP0Zsr'}],
#                                     'user_mentions': [{'id': 1032904812281520100,
#                                                        'id_str': '1032904812281520128',
#                                                        'indices': [0, 16],
#                                                        'name': 'SylviaD',
#                                                        'screen_name': 'SylviaD32911201'}]},
#                        'favorite_count': 1,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 1212166834197106700,
#                        'id_str': '1212166834197106688',
#                        'in_reply_to_screen_name': 'SylviaD32911201',
#                        'in_reply_to_status_id': 1212137403227361300,
#                        'in_reply_to_status_id_str': '1212137403227361280',
#                        'in_reply_to_user_id': 1032904812281520100,
#                        'in_reply_to_user_id_str': '1032904812281520128',
#                        'is_quote_status': False,
#                        'lang': 'en',
#                        'metadata': {'iso_language_code': 'en',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'possibly_sensitive': False,
#                        'retweet_count': 1,
#                        'retweeted': False,
#                        'source': '<a href="https://mobile.twitter.com" '
#                                  'rel="nofollow">Twitter Web App</a>',
#                        'text': '@SylviaD32911201 Why forests are allowed to '
#                                'build up fuel loads to the dangerous levels '
#                                'that guarantee a super hot… '
#                                'https://t.co/BaM0MP0Zsr',
#                        'truncated': True,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Thu Apr 19 06:12:30 +0000 2012',
#                                 'default_profile': False,
#                                 'default_profile_image': False,
#                                 'description': 'https://t.co/EzfpAkkzCl  A '
#                                                'Conservative Voice in Global '
#                                                'News https://t.co/WyXFtphuGx',
#                                 'entities': {'description': {'urls': [{'display_url': 'POWERGLOBAL.US',
#                                                                        'expanded_url': 'http://POWERGLOBAL.US',
#                                                                        'indices': [0,
#                                                                                    23],
#                                                                        'url': 'https://t.co/EzfpAkkzCl'},
#                                                                       {'display_url': 'Powerglobal.us',
#                                                                        'expanded_url': 'http://www.Powerglobal.us',
#                                                                        'indices': [61,
#                                                                                    84],
#                                                                        'url': 'https://t.co/WyXFtphuGx'}]},
#                                              'url': {'urls': [{'display_url': 'powerglobal.us',
#                                                                'expanded_url': 'http://www.powerglobal.us',
#                                                                'indices': [0,
#                                                                            23],
#                                                                'url': 'https://t.co/D6jTgB0FiT'}]}},
#                                 'favourites_count': 578715,
#                                 'follow_request_sent': False,
#                                 'followers_count': 34404,
#                                 'following': False,
#                                 'friends_count': 37034,
#                                 'geo_enabled': False,
#                                 'has_extended_profile': False,
#                                 'id': 557468072,
#                                 'id_str': '557468072',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': None,
#                                 'listed_count': 239,
#                                 'location': 'Sydney, New South Wales',
#                                 'name': 'Powerglobal',
#                                 'notifications': False,
#                                 'profile_background_color': '000000',
#                                 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                 'profile_background_tile': False,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/557468072/1461391153',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/841097251061608449/zZ-JfynT_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/841097251061608449/zZ-JfynT_normal.jpg',
#                                 'profile_link_color': '1B95E0',
#                                 'profile_sidebar_border_color': '000000',
#                                 'profile_sidebar_fill_color': '000000',
#                                 'profile_text_color': '000000',
#                                 'profile_use_background_image': False,
#                                 'protected': False,
#                                 'screen_name': 'powerglobalus',
#                                 'statuses_count': 540430,
#                                 'time_zone': None,
#                                 'translator_type': 'regular',
#                                 'url': 'https://t.co/D6jTgB0FiT',
#                                 'utc_offset': None,
#                                 'verified': False}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web '
#             'App</a>',
#   'text': 'RT @powerglobalus: @SylviaD32911201 Why forests are allowed to '
#           'build up fuel loads to the dangerous levels that guarantee a super '
#           'hot out o…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Thu Apr 19 06:12:30 +0000 2012',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'https://t.co/EzfpAkkzCl  A Conservative Voice in '
#                           'Global News https://t.co/WyXFtphuGx',
#            'entities': {'description': {'urls': [{'display_url': 'POWERGLOBAL.US',
#                                                   'expanded_url': 'http://POWERGLOBAL.US',
#                                                   'indices': [0, 23],
#                                                   'url': 'https://t.co/EzfpAkkzCl'},
#                                                  {'display_url': 'Powerglobal.us',
#                                                   'expanded_url': 'http://www.Powerglobal.us',
#                                                   'indices': [61, 84],
#                                                   'url': 'https://t.co/WyXFtphuGx'}]},
#                         'url': {'urls': [{'display_url': 'powerglobal.us',
#                                           'expanded_url': 'http://www.powerglobal.us',
#                                           'indices': [0, 23],
#                                           'url': 'https://t.co/D6jTgB0FiT'}]}},
#            'favourites_count': 578715,
#            'follow_request_sent': False,
#            'followers_count': 34404,
#            'following': False,
#            'friends_count': 37034,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 557468072,
#            'id_str': '557468072',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 239,
#            'location': 'Sydney, New South Wales',
#            'name': 'Powerglobal',
#            'notifications': False,
#            'profile_background_color': '000000',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/557468072/1461391153',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/841097251061608449/zZ-JfynT_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/841097251061608449/zZ-JfynT_normal.jpg',
#            'profile_link_color': '1B95E0',
#            'profile_sidebar_border_color': '000000',
#            'profile_sidebar_fill_color': '000000',
#            'profile_text_color': '000000',
#            'profile_use_background_image': False,
#            'protected': False,
#            'screen_name': 'powerglobalus',
#            'statuses_count': 540430,
#            'time_zone': None,
#            'translator_type': 'regular',
#            'url': 'https://t.co/D6jTgB0FiT',
#            'utc_offset': None,
#            'verified': False}},
#  {'_id': '1212167169036783617',
#   '_rev': '1-e71eada18986df51b3137deb20fda054',
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 01 00:22:28 +0000 2020',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 316896321,
#                                   'id_str': '316896321',
#                                   'indices': [0, 11],
#                                   'name': 'Kristen Spillane',
#                                   'screen_name': 'KNSpillane'},
#                                  {'id': 12492842,
#                                   'id_str': '12492842',
#                                   'indices': [12, 19],
#                                   'name': 'Citrix',
#                                   'screen_name': 'citrix'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1212167169036783600,
#   'id_str': '1212167169036783617',
#   'in_reply_to_screen_name': 'KNSpillane',
#   'in_reply_to_status_id': 1212101823546478600,
#   'in_reply_to_status_id_str': '1212101823546478592',
#   'in_reply_to_user_id': 316896321,
#   'in_reply_to_user_id_str': '316896321',
#   'is_quote_status': False,
#   'lang': 'en',
#   'location': 'sydney',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': '@KNSpillane @citrix Yep. Was pretty amazing.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Tue Sep 08 07:42:03 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Field CTO @Citrix',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'citrix.com',
#                                           'expanded_url': 'http://citrix.com',
#                                           'indices': [0, 23],
#                                           'url': 'https://t.co/TthfRMBCT7'}]}},
#            'favourites_count': 2230,
#            'follow_request_sent': False,
#            'followers_count': 357,
#            'following': False,
#            'friends_count': 238,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 72499570,
#            'id_str': '72499570',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 11,
#            'location': 'Sydney, Australia',
#            'name': 'Safi Obeidullah',
#            'notifications': False,
#            'profile_background_color': '000000',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/72499570/1552866928',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/1183715930611650561/GG5yJCTB_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183715930611650561/GG5yJCTB_normal.jpg',
#            'profile_link_color': 'ABB8C2',
#            'profile_sidebar_border_color': '000000',
#            'profile_sidebar_fill_color': '000000',
#            'profile_text_color': '000000',
#            'profile_use_background_image': False,
#            'protected': False,
#            'screen_name': 'safio7',
#            'statuses_count': 791,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': 'https://t.co/TthfRMBCT7',
#            'utc_offset': None,
#            'verified': False}},
#  {'_id': '1212167170362347525',
#   '_rev': '1-54da054bbf32816a491189bb69aabbe1',
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 01 00:22:29 +0000 2020',
#   'entities': {'hashtags': [{'indices': [48, 52], 'text': 'RBD'}],
#                'media': [{'display_url': 'pic.twitter.com/Q0TFuKbPdw',
#                           'expanded_url': 'https://twitter.com/itsluso/status/1212166836705517568/photo/1',
#                           'id': 1212166830011355100,
#                           'id_str': '1212166830011355137',
#                           'indices': [53, 76],
#                           'media_url': 'http://pbs.twimg.com/media/ENJ7Tz9WkAEVtc7.jpg',
#                           'media_url_https': 'https://pbs.twimg.com/media/ENJ7Tz9WkAEVtc7.jpg',
#                           'sizes': {'large': {'h': 1565,
#                                               'resize': 'fit',
#                                               'w': 1023},
#                                     'medium': {'h': 1200,
#                                                'resize': 'fit',
#                                                'w': 784},
#                                     'small': {'h': 680,
#                                               'resize': 'fit',
#                                               'w': 444},
#                                     'thumb': {'h': 150,
#                                               'resize': 'crop',
#                                               'w': 150}},
#                           'source_status_id': 1212166836705517600,
#                           'source_status_id_str': '1212166836705517568',
#                           'source_user_id': 1711621316,
#                           'source_user_id_str': '1711621316',
#                           'type': 'photo',
#                           'url': 'https://t.co/Q0TFuKbPdw'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 1711621316,
#                                   'id_str': '1711621316',
#                                   'indices': [3, 11],
#                                   'name': 'Anderson Luso',
#                                   'screen_name': 'itsluso'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Q0TFuKbPdw',
#                                    'expanded_url': 'https://twitter.com/itsluso/status/1212166836705517568/photo/1',
#                                    'id': 1212166830011355100,
#                                    'id_str': '1212166830011355137',
#                                    'indices': [53, 76],
#                                    'media_url': 'http://pbs.twimg.com/media/ENJ7Tz9WkAEVtc7.jpg',
#                                    'media_url_https': 'https://pbs.twimg.com/media/ENJ7Tz9WkAEVtc7.jpg',
#                                    'sizes': {'large': {'h': 1565,
#                                                        'resize': 'fit',
#                                                        'w': 1023},
#                                              'medium': {'h': 1200,
#                                                         'resize': 'fit',
#                                                         'w': 784},
#                                              'small': {'h': 680,
#                                                        'resize': 'fit',
#                                                        'w': 444},
#                                              'thumb': {'h': 150,
#                                                        'resize': 'crop',
#                                                        'w': 150}},
#                                    'source_status_id': 1212166836705517600,
#                                    'source_status_id_str': '1212166836705517568',
#                                    'source_user_id': 1711621316,
#                                    'source_user_id_str': '1711621316',
#                                    'type': 'photo',
#                                    'url': 'https://t.co/Q0TFuKbPdw'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1212167170362347500,
#   'id_str': '1212167170362347525',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'pt',
#   'location': 'sydney',
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Wed Jan 01 00:21:09 +0000 2020',
#                        'entities': {'hashtags': [{'indices': [35, 39],
#                                                   'text': 'RBD'}],
#                                     'media': [{'display_url': 'pic.twitter.com/Q0TFuKbPdw',
#                                                'expanded_url': 'https://twitter.com/itsluso/status/1212166836705517568/photo/1',
#                                                'id': 1212166830011355100,
#                                                'id_str': '1212166830011355137',
#                                                'indices': [40, 63],
#                                                'media_url': 'http://pbs.twimg.com/media/ENJ7Tz9WkAEVtc7.jpg',
#                                                'media_url_https': 'https://pbs.twimg.com/media/ENJ7Tz9WkAEVtc7.jpg',
#                                                'sizes': {'large': {'h': 1565,
#                                                                    'resize': 'fit',
#                                                                    'w': 1023},
#                                                          'medium': {'h': 1200,
#                                                                     'resize': 'fit',
#                                                                     'w': 784},
#                                                          'small': {'h': 680,
#                                                                    'resize': 'fit',
#                                                                    'w': 444},
#                                                          'thumb': {'h': 150,
#                                                                    'resize': 'crop',
#                                                                    'w': 150}},
#                                                'type': 'photo',
#                                                'url': 'https://t.co/Q0TFuKbPdw'}],
#                                     'symbols': [],
#                                     'urls': [],
#                                     'user_mentions': []},
#                        'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Q0TFuKbPdw',
#                                                         'expanded_url': 'https://twitter.com/itsluso/status/1212166836705517568/photo/1',
#                                                         'id': 1212166830011355100,
#                                                         'id_str': '1212166830011355137',
#                                                         'indices': [40, 63],
#                                                         'media_url': 'http://pbs.twimg.com/media/ENJ7Tz9WkAEVtc7.jpg',
#                                                         'media_url_https': 'https://pbs.twimg.com/media/ENJ7Tz9WkAEVtc7.jpg',
#                                                         'sizes': {'large': {'h': 1565,
#                                                                             'resize': 'fit',
#                                                                             'w': 1023},
#                                                                   'medium': {'h': 1200,
#                                                                              'resize': 'fit',
#                                                                              'w': 784},
#                                                                   'small': {'h': 680,
#                                                                             'resize': 'fit',
#                                                                             'w': 444},
#                                                                   'thumb': {'h': 150,
#                                                                             'resize': 'crop',
#                                                                             'w': 150}},
#                                                         'type': 'photo',
#                                                         'url': 'https://t.co/Q0TFuKbPdw'}]},
#                        'favorite_count': 3,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 1212166836705517600,
#                        'id_str': '1212166836705517568',
#                        'in_reply_to_screen_name': None,
#                        'in_reply_to_status_id': None,
#                        'in_reply_to_status_id_str': None,
#                        'in_reply_to_user_id': None,
#                        'in_reply_to_user_id_str': None,
#                        'is_quote_status': False,
#                        'lang': 'pt',
#                        'metadata': {'iso_language_code': 'pt',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'possibly_sensitive': False,
#                        'retweet_count': 2,
#                        'retweeted': False,
#                        'source': '<a href="http://twitter.com/download/iphone" '
#                                  'rel="nofollow">Twitter for iPhone</a>',
#                        'text': 'Fechando 2019 com chave de ouro ❤️ #RBD '
#                                'https://t.co/Q0TFuKbPdw',
#                        'truncated': False,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Fri Aug 30 02:54:17 +0000 2013',
#                                 'default_profile': False,
#                                 'default_profile_image': False,
#                                 'description': 'BH, Uai 🔺 / '
#                                                'https://t.co/WXzXgwVHLf',
#                                 'entities': {'description': {'urls': [{'display_url': 'youtube.com/itsluso',
#                                                                        'expanded_url': 'http://youtube.com/itsluso',
#                                                                        'indices': [12,
#                                                                                    35],
#                                                                        'url': 'https://t.co/WXzXgwVHLf'}]},
#                                              'url': {'urls': [{'display_url': 'instagram.com/itsluso',
#                                                                'expanded_url': 'http://instagram.com/itsluso',
#                                                                'indices': [0,
#                                                                            23],
#                                                                'url': 'https://t.co/i4o7Exhf2j'}]}},
#                                 'favourites_count': 335,
#                                 'follow_request_sent': False,
#                                 'followers_count': 17161,
#                                 'following': False,
#                                 'friends_count': 8723,
#                                 'geo_enabled': True,
#                                 'has_extended_profile': True,
#                                 'id': 1711621316,
#                                 'id_str': '1711621316',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': None,
#                                 'listed_count': 94,
#                                 'location': 'P.Sherman,42Wallaby Way,Sydney',
#                                 'name': 'Anderson Luso',
#                                 'notifications': False,
#                                 'profile_background_color': 'EBF2F5',
#                                 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                 'profile_background_tile': True,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1711621316/1570968147',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/1209579738412523520/5xTj19qT_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1209579738412523520/5xTj19qT_normal.jpg',
#                                 'profile_link_color': '226655',
#                                 'profile_sidebar_border_color': 'FFFFFF',
#                                 'profile_sidebar_fill_color': 'DDEEF6',
#                                 'profile_text_color': '333333',
#                                 'profile_use_background_image': True,
#                                 'protected': False,
#                                 'screen_name': 'itsluso',
#                                 'statuses_count': 22582,
#                                 'time_zone': None,
#                                 'translator_type': 'regular',
#                                 'url': 'https://t.co/i4o7Exhf2j',
#                                 'utc_offset': None,
#                                 'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" '
#             'rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @itsluso: Fechando 2019 com chave de ouro ❤️ #RBD '
#           'https://t.co/Q0TFuKbPdw',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Fri Sep 05 22:13:00 +0000 2008',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'quais são as cores que são suas cores de '
#                           'predileção?',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 15473,
#            'follow_request_sent': False,
#            'followers_count': 851,
#            'following': False,
#            'friends_count': 1604,
#            'geo_enabled': True,
#            'has_extended_profile': True,
#            'id': 16150397,
#            'id_str': '16150397',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 0,
#            'location': 'brasil - são paulo - sp',
#            'name': 'mateixe',
#            'notifications': False,
#            'profile_background_color': 'FFFFFF',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': True,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16150397/1567529108',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/1168928303803183104/XAvRzCQg_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168928303803183104/XAvRzCQg_normal.jpg',
#            'profile_link_color': '000000',
#            'profile_sidebar_border_color': 'FFFFFF',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'mateixe',
#            'statuses_count': 29478,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}},
#  {'_id': '1212167172023128064',
#   '_rev': '1-95634b96b13aed0e55012f97a6cd5e19',
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 01 00:22:29 +0000 2020',
#   'entities': {'hashtags': [{'indices': [48, 55], 'text': 'Bilpin'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 833224452787761200,
#                                   'id_str': '833224452787761152',
#                                   'indices': [3, 16],
#                                   'name': 'Elle DeSylva 🇦🇺🌊',
#                                   'screen_name': 'elle_desylva'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1212167172023128000,
#   'id_str': '1212167172023128064',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'location': 'sydney',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 19,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Tue Dec 31 02:39:25 +0000 2019',
#                        'entities': {'hashtags': [{'indices': [30, 37],
#                                                   'text': 'Bilpin'}],
#                                     'symbols': [],
#                                     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                               'expanded_url': 'https://twitter.com/i/web/status/1211839242936045568',
#                                               'indices': [117, 140],
#                                               'url': 'https://t.co/20ub28eZnI'}],
#                                     'user_mentions': []},
#                        'favorite_count': 27,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 1211839242936045600,
#                        'id_str': '1211839242936045568',
#                        'in_reply_to_screen_name': None,
#                        'in_reply_to_status_id': None,
#                        'in_reply_to_status_id_str': None,
#                        'in_reply_to_user_id': None,
#                        'in_reply_to_user_id_str': None,
#                        'is_quote_status': False,
#                        'lang': 'en',
#                        'metadata': {'iso_language_code': 'en',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'possibly_sensitive': False,
#                        'retweet_count': 19,
#                        'retweeted': False,
#                        'source': '<a href="http://twitter.com/download/iphone" '
#                                  'rel="nofollow">Twitter for iPhone</a>',
#                        'text': 'Want to help the community of #Bilpin? Buy '
#                                'their products – you can do this online and it '
#                                'really does help. Their c… '
#                                'https://t.co/20ub28eZnI',
#                        'truncated': True,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Sun Feb 19 07:59:24 +0000 2017',
#                                 'default_profile': False,
#                                 'default_profile_image': False,
#                                 'description': "Aussie alarmed about the USA's "
#                                                'descent into an Orwellian '
#                                                'nightmare. What kind of world '
#                                                'are we leaving behind? | Used '
#                                                'to be мiѕѕ иуєт | Hooray for '
#                                                'im🍑ment! \U0001f9f7',
#                                 'entities': {'description': {'urls': []},
#                                              'url': {'urls': [{'display_url': 'pscp.tv/MissNyetTrump/…',
#                                                                'expanded_url': 'https://www.pscp.tv/MissNyetTrump/follow',
#                                                                'indices': [0,
#                                                                            23],
#                                                                'url': 'https://t.co/N8YMne4RS4'}]}},
#                                 'favourites_count': 247028,
#                                 'follow_request_sent': False,
#                                 'followers_count': 62573,
#                                 'following': False,
#                                 'friends_count': 53127,
#                                 'geo_enabled': True,
#                                 'has_extended_profile': False,
#                                 'id': 833224452787761200,
#                                 'id_str': '833224452787761152',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': None,
#                                 'listed_count': 142,
#                                 'location': 'Sydney, Australia',
#                                 'name': 'Elle DeSylva 🇦🇺🌊',
#                                 'notifications': False,
#                                 'profile_background_color': '000000',
#                                 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                 'profile_background_tile': False,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/833224452787761152/1573620301',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/1208207583724457984/mdyc13DT_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1208207583724457984/mdyc13DT_normal.jpg',
#                                 'profile_link_color': '19CF86',
#                                 'profile_sidebar_border_color': '000000',
#                                 'profile_sidebar_fill_color': '000000',
#                                 'profile_text_color': '000000',
#                                 'profile_use_background_image': False,
#                                 'protected': False,
#                                 'screen_name': 'elle_desylva',
#                                 'statuses_count': 91372,
#                                 'time_zone': None,
#                                 'translator_type': 'none',
#                                 'url': 'https://t.co/N8YMne4RS4',
#                                 'utc_offset': None,
#                                 'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @elle_desylva: Want to help the community of #Bilpin? Buy their '
#           'products – you can do this online and it really does help. Their '
#           'cider a…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Sun Feb 19 07:59:24 +0000 2017',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': "Aussie alarmed about the USA's descent into an "
#                           'Orwellian nightmare. What kind of world are we '
#                           'leaving behind? | Used to be мiѕѕ иуєт | Hooray for '
#                           'im🍑ment! \U0001f9f7',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'pscp.tv/MissNyetTrump/…',
#                                           'expanded_url': 'https://www.pscp.tv/MissNyetTrump/follow',
#                                           'indices': [0, 23],
#                                           'url': 'https://t.co/N8YMne4RS4'}]}},
#            'favourites_count': 247028,
#            'follow_request_sent': False,
#            'followers_count': 62573,
#            'following': False,
#            'friends_count': 53127,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 833224452787761200,
#            'id_str': '833224452787761152',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 142,
#            'location': 'Sydney, Australia',
#            'name': 'Elle DeSylva 🇦🇺🌊',
#            'notifications': False,
#            'profile_background_color': '000000',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/833224452787761152/1573620301',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/1208207583724457984/mdyc13DT_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1208207583724457984/mdyc13DT_normal.jpg',
#            'profile_link_color': '19CF86',
#            'profile_sidebar_border_color': '000000',
#            'profile_sidebar_fill_color': '000000',
#            'profile_text_color': '000000',
#            'profile_use_background_image': False,
#            'protected': False,
#            'screen_name': 'elle_desylva',
#            'statuses_count': 91372,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': 'https://t.co/N8YMne4RS4',
#            'utc_offset': None,
#            'verified': False}},
#  {'_id': '1212167172853649408',
#   '_rev': '1-818192f1240ae33481867d3418cef9c2',
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 01 00:22:29 +0000 2020',
#   'entities': {'hashtags': [{'indices': [96, 112], 'text': 'RiseofSkywalker'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 27619759,
#                                   'id_str': '27619759',
#                                   'indices': [3, 11],
#                                   'name': 'Thuy Ong 🥞',
#                                   'screen_name': 'ThuyOng'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1212167172853649400,
#   'id_str': '1212167172853649408',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'location': 'sydney',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 51,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Tue Dec 24 23:35:18 +0000 2019',
#                        'entities': {'hashtags': [{'indices': [83, 99],
#                                                   'text': 'RiseofSkywalker'}],
#                                     'symbols': [],
#                                     'urls': [],
#                                     'user_mentions': []},
#                        'favorite_count': 245,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 1209618582671220700,
#                        'id_str': '1209618582671220737',
#                        'in_reply_to_screen_name': None,
#                        'in_reply_to_status_id': None,
#                        'in_reply_to_status_id_str': None,
#                        'in_reply_to_user_id': None,
#                        'in_reply_to_user_id_str': None,
#                        'is_quote_status': False,
#                        'lang': 'en',
#                        'metadata': {'iso_language_code': 'en',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'retweet_count': 51,
#                        'retweeted': False,
#                        'source': '<a href="https://mobile.twitter.com" '
#                                  'rel="nofollow">Twitter Web App</a>',
#                        'text': 'Realising that Rise of Skywalker could also be '
#                                'called The Emperor’s New Groove '
#                                '\U0001f999\U0001f999\U0001f999 '
#                                '#RiseofSkywalker',
#                        'truncated': False,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Mon Mar 30 11:25:37 +0000 2009',
#                                 'default_profile': False,
#                                 'default_profile_image': False,
#                                 'description': 'Breaking News at '
#                                                '@Bloomberg/@Business. I like '
#                                                'films, tech, food, photography '
#                                                '& shiny things. 🐨SAY HI: '
#                                                'hong35@bloomberg.net 🥞Views my '
#                                                "own (& my mama's)",
#                                 'entities': {'description': {'urls': []},
#                                              'url': {'urls': [{'display_url': 'linktr.ee/heyitstwee',
#                                                                'expanded_url': 'https://linktr.ee/heyitstwee',
#                                                                'indices': [0,
#                                                                            23],
#                                                                'url': 'https://t.co/5RdKLLWcCo'}]}},
#                                 'favourites_count': 35764,
#                                 'follow_request_sent': False,
#                                 'followers_count': 3120,
#                                 'following': False,
#                                 'friends_count': 999,
#                                 'geo_enabled': True,
#                                 'has_extended_profile': False,
#                                 'id': 27619759,
#                                 'id_str': '27619759',
#                                 'is_translation_enabled': True,
#                                 'is_translator': False,
#                                 'lang': None,
#                                 'listed_count': 118,
#                                 'location': 'Sydney',
#                                 'name': 'Thuy Ong 🥞',
#                                 'notifications': False,
#                                 'profile_background_color': 'E5E5E5',
#                                 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#                                 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#                                 'profile_background_tile': True,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27619759/1569401983',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/649950533831098370/ixkcTYji_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/649950533831098370/ixkcTYji_normal.jpg',
#                                 'profile_link_color': '91D2FA',
#                                 'profile_sidebar_border_color': 'DA78A1',
#                                 'profile_sidebar_fill_color': '4CBAB9',
#                                 'profile_text_color': '474946',
#                                 'profile_use_background_image': True,
#                                 'protected': False,
#                                 'screen_name': 'ThuyOng',
#                                 'statuses_count': 1508,
#                                 'time_zone': None,
#                                 'translator_type': 'none',
#                                 'url': 'https://t.co/5RdKLLWcCo',
#                                 'utc_offset': None,
#                                 'verified': True}},
# ...
#                     'lang': 'en',
#                     'metadata': {'iso_language_code': 'en',
#                                  'result_type': 'recent'},
#                     'place': None,
#                     'possibly_sensitive': False,
#                     'retweet_count': 164,
#                     'retweeted': False,
#                     'source': '<a '
#                               'href="https://about.twitter.com/products/tweetdeck" '
#                               'rel="nofollow">TweetDeck</a>',
#                     'text': 'Imagery from Sentinel-2A showing the Clyde '
#                             'Mountain Fire (near Batemans Bay, NSW) and '
#                             'associated cumulus flammageni… '
#                             'https://t.co/VivgSHk8wX',
#                     'truncated': True,
#                     'user': {'contributors_enabled': False,
#                              'created_at': 'Thu Sep 30 06:35:55 +0000 2010',
#                              'default_profile': True,
#                              'default_profile_image': False,
#                              'description': 'Enjoying the insights of '
#                                             'meteorologists, developers, '
#                                             'cartographers, cricketers, '
#                                             'aviators, journalists, thinking '
#                                             'Christians and others. Developer '
#                                             '@weatherzone',
#                              'entities': {'description': {'urls': []},
#                                           'url': {'urls': [{'display_url': 'anero.id',
#                                                             'expanded_url': 'https://anero.id',
#                                                             'indices': [0, 23],
#                                                             'url': 'https://t.co/2A78V8CVmw'}]}},
#                              'favourites_count': 959,
#                              'follow_request_sent': False,
#                              'followers_count': 2168,
#                              'following': False,
#                              'friends_count': 293,
#                              'geo_enabled': True,
#                              'has_extended_profile': False,
#                              'id': 196922392,
#                              'id_str': '196922392',
#                              'is_translation_enabled': False,
#                              'is_translator': False,
#                              'lang': None,
#                              'listed_count': 67,
#                              'location': 'Mittagong, Australia',
#                              'name': 'Andrew Miskelly',
#                              'notifications': False,
#                              'profile_background_color': 'C0DEED',
#                              'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                              'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                              'profile_background_tile': False,
#                              'profile_banner_url': 'https://pbs.twimg.com/profile_banners/196922392/1400159024',
#                              'profile_image_url': 'http://pbs.twimg.com/profile_images/819509458447450112/Nvgg3v6N_normal.jpg',
#                              'profile_image_url_https': 'https://pbs.twimg.com/profile_images/819509458447450112/Nvgg3v6N_normal.jpg',
#                              'profile_link_color': '1DA1F2',
#                              'profile_sidebar_border_color': 'C0DEED',
#                              'profile_sidebar_fill_color': 'DDEEF6',
#                              'profile_text_color': '333333',
#                              'profile_use_background_image': True,
#                              'protected': False,
#                              'screen_name': 'andrewmiskelly',
#                              'statuses_count': 2975,
#                              'time_zone': None,
#                              'translator_type': 'none',
#                              'url': 'https://t.co/2A78V8CVmw',
#                              'utc_offset': None,
#                              'verified': False}},
#   'quoted_status_id': 1211944488156876800,
#   'quoted_status_id_str': '1211944488156876802',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': '@WarrenSharpe5 hope you’re safe and sound mate '
#           'https://t.co/RzHVRHqGif',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Sat Jan 07 09:31:58 +0000 2012',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': 'Father, engineer, fisherman, @ipweansw & @ipwea '
#                           'Board Member. All comments my own.',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 3963,
#            'follow_request_sent': False,
#            'followers_count': 622,
#            'following': False,
#            'friends_count': 751,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 457354497,
#            'id_str': '457354497',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 37,
#            'location': 'Blue Mountains, New South Wales',
#            'name': 'Will Barton',
#            'notifications': False,
#            'profile_background_color': 'C0DEED',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/457354497/1491727760',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/1738950973/20111123_0094_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1738950973/20111123_0094_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'willb_photos',
#            'statuses_count': 12796,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}},
#  {'_id': '1212167181909155840',
#   '_rev': '1-08ef8bb7f64222612aa904719ff6ce4c',
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 01 00:22:31 +0000 2020',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                          'expanded_url': 'https://twitter.com/i/web/status/1212167181909155840',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/g5VOHhH6KD'}],
#                'user_mentions': [{'id': 16264803,
#                                   'id_str': '16264803',
#                                   'indices': [0, 12],
#                                   'name': 'Bravo Echo Hotel '
#                                           '7️⃣3️⃣🔭👨🏼\u200d🚀👽✨💫',
#                                   'screen_name': 'brett7three'},
#                                  {'id': 1902400610,
#                                   'id_str': '1902400610',
#                                   'indices': [13, 28],
#                                   'name': 'TruthTalker -TEXT Trump to 88022 🇺🇸',
#                                   'screen_name': 'TruthTalkerUSA'},
#                                  {'id': 3406938525,
#                                   'id_str': '3406938525',
#                                   'indices': [29, 45],
#                                   'name': 'thebradfordfile™',
#                                   'screen_name': 'thebradfordfile'},
#                                  {'id': 17629860,
#                                   'id_str': '17629860',
#                                   'indices': [46, 50],
#                                   'name': 'FBI',
#                                   'screen_name': 'FBI'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1212167181909155800,
#   'id_str': '1212167181909155840',
#   'in_reply_to_screen_name': 'brett7three',
#   'in_reply_to_status_id': 1212042825266860000,
#   'in_reply_to_status_id_str': '1212042825266860033',
#   'in_reply_to_user_id': 16264803,
#   'in_reply_to_user_id_str': '16264803',
#   'is_quote_status': False,
#   'lang': 'en',
#   'location': 'sydney',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': '@brett7three @TruthTalkerUSA @thebradfordfile @FBI No they won’t '
#           'because there was NO coup...another conspiracy the… '
#           'https://t.co/g5VOHhH6KD',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Mon Jun 21 11:48:44 +0000 2010',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': 'Renaissance Man - techie, writer, speaker, '
#                           'film-maker, futurist.',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 31887,
#            'follow_request_sent': False,
#            'followers_count': 1794,
#            'following': False,
#            'friends_count': 5004,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 157972164,
#            'id_str': '157972164',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 216,
#            'location': 'Sydney Australia',
#            'name': 'Stephen Chase',
#            'notifications': False,
#            'profile_background_color': 'C0DEED',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/157972164/1397432546',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/455488729730142208/FKIZ-XXq_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/455488729730142208/FKIZ-XXq_normal.jpeg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'chaser1066',
#            'statuses_count': 62591,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}},
#  {'_id': '1212167182055903233',
#   '_rev': '1-e4b3d15ae05e597045595f1640e27125',
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 01 00:22:31 +0000 2020',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 577027901,
#                                   'id_str': '577027901',
#                                   'indices': [0, 11],
#                                   'name': 'Sir Craig Diebert',
#                                   'screen_name': 'eldieberto'},
#                                  {'id': 42744260,
#                                   'id_str': '42744260',
#                                   'indices': [12, 18],
#                                   'name': 'Fire and Rescue NSW',
#                                   'screen_name': 'FRNSW'},
#                                  {'id': 10926872,
#                                   'id_str': '10926872',
#                                   'indices': [19, 26],
#                                   'name': 'NSW RFS',
#                                   'screen_name': 'NSWRFS'},
#                                  {'id': 34116377,
#                                   'id_str': '34116377',
#                                   'indices': [27, 43],
#                                   'name': 'Scott Morrison',
#                                   'screen_name': 'ScottMorrisonMP'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1212167182055903200,
#   'id_str': '1212167182055903233',
#   'in_reply_to_screen_name': 'eldieberto',
#   'in_reply_to_status_id': 1211988748650463200,
#   'in_reply_to_status_id_str': '1211988748650463232',
#   'in_reply_to_user_id': 577027901,
#   'in_reply_to_user_id_str': '577027901',
#   'is_quote_status': False,
#   'lang': 'en',
#   'location': 'sydney',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web '
#             'App</a>',
#   'text': '@eldieberto @FRNSW @NSWRFS @ScottMorrisonMP These are the pro '
#           'trucks, they do have outside sprinklers and they have fire '
#           'retardant blankets.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Dec 11 03:22:50 +0000 2019',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': '#actuallyautistic mentor (I hope) Aspect Think '
#                           'Tank. Teacher for 30 years. Wish I was teaching '
#                           'Autistics.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'superprof.com.au/the-autistic-e…',
#                                           'expanded_url': 'https://www.superprof.com.au/the-autistic-educator-sydney-nsw-actuallyautistic-educator-with-lifetim',
#                                           'indices': [0, 23],
#                                           'url': 'https://t.co/YUB56Jj4Y4'}]}},
#            'favourites_count': 356,
#            'follow_request_sent': False,
#            'followers_count': 90,
#            'following': False,
#            'friends_count': 499,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 1204602305464553500,
#            'id_str': '1204602305464553472',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 3,
#            'location': 'Sydney',
#            'name': 'Theautisticeducator',
#            'notifications': False,
#            'profile_background_color': 'F5F8FA',
#            'profile_background_image_url': None,
#            'profile_background_image_url_https': None,
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/1204605991687340033/miFJYl9i_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1204605991687340033/miFJYl9i_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'Theautisticedu1',
#            'statuses_count': 436,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': 'https://t.co/YUB56Jj4Y4',
#            'utc_offset': None,
#            'verified': False}}]

# %% [markdown]
# ## Search for Hashtags
#
# Array of [Hashtag Objects](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/entities-object#hashtags) is under [Entities data dictionary](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/entities-object#entitiesobject)

# %%
def extract_hashtags(tweet):
  """
  Extract hashtags from Tweet Data Dictionary and convert to lowercase
  tweet: Tweet Data Dictionary
  """

  if not tweet:
    return []

  hashtags = tweet["entities"]["hashtags"]
  names = [tag["text"].lower() for tag in hashtags] # lowercased hashtag names (without #)

  return names

htcounts = Counter()
for t in tweets:
  names = extract_hashtags(t)
  htcounts.update(names)
print(htcounts)
# Out:
# Counter({'climatechange': 6, 'scottyfrommarketing': 6, 'auspol': 6, 'australiaburns': 5, 'sonicmovie': 4, 'bushfiresnsw': 3, 'nswfires': 3, 'sydnye': 2, 'sydney': 2, 'climate': 2, 'happynewyear': 2, 'australianfires': 2, 'fireworks': 2, 'nye2020': 2, 'canberra': 2, 'เป๊กผลิตโชค': 2, 'liarfromtheshire': 2, 'morrisonfires': 2, 'countdown2020withpeck': 2, 'nye': 2, 'configmgr': 1, 'ilovesydney': 1, 'sideproject': 1, 'makers': 1, 'bulltitts': 1, 'fatca': 1, 'decadechallenge': 1, '2010vs2020': 1, 'abc': 1, 'priorities': 1, 'stowaway': 1, 'joseout': 1, 'duindorp': 1, 'gardening': 1, 'urbangardens': 1, 'newyearsday2020': 1, 'smoko': 1, 'youvestolenmychildhood': 1, 'howdareyou': 1, 'peoplearedying': 1, 'coalman': 1, 'brisbane': 1, 'labor': 1, 'loveislandau': 1, 'cheers': 1, 'skål': 1, 'avstwitterpsychic': 1, 'goavsgo': 1, 'climatecriminals': 1, '9news': 1, 'theirabc': 1, 'primeminister': 1, 'sackfomo': 1, 'sackscummo': 1, 'southcoastfires': 1, 'bushfires': 1, 'nswpol': 1, 'peckpalitchoke': 1, 'torvsmin': 1, 'workout': 1, 'aisbangkokcountdown2020xpeck': 1, 'เค้าท์ดาวน์2020กับพี่เป๊ก': 1, 'fe3h': 1, 'sylvix': 1, 'bloodsun': 1, 'energyaccess': 1, 'bringbacktony': 1, 'newyearresolutions': 1, 'เคาท์ดาวน์2020กับพี่เป๊ก': 1, 'my': 1, 'twitter': 1, 'hacked': 1, 'yay': 1, 'freaking': 1, 'nigeria': 1, 'deniers': 1, 'burnnewscorp': 1, 'littlemanmorrison': 1, 'adapt': 1, 'hongkongprotest': 1, 'denierfromtheshire': 1, 'อิจฉาจ้า': 1, 'เศร้า': 1, '500daysofsummer': 1, 'nowplaying': 1, 'scottyfommarketing': 1, 'aliens': 1, 'area51': 1, 'hny2020': 1, 'ausmedia': 1, 'msm': 1, 'victoriafires': 1, 'wankpuffin': 1, 'lockhimup': 1, 'quote': 1, 'tesla': 1, 'israel': 1, 'electriccar': 1, 'australia': 1, 'happynewyear2020': 1, 'bolsonaromaisforteem2020': 1, 'scottludlum': 1, 'koalakiller': 1, 'climateemergency': 1, 'adventure': 1, 'bedaring': 1, 'rbd': 1, 'bilpin': 1, 'riseofskywalker': 1, 'texperkins': 1, 'thefinger': 1})

# %%
htcounts.most_common(10)
# Out:
# [('climatechange', 6),
#  ('scottyfrommarketing', 6),
#  ('auspol', 6),
#  ('australiaburns', 5),
#  ('sonicmovie', 4),
#  ('bushfiresnsw', 3),
#  ('nswfires', 3),
#  ('sydnye', 2),
#  ('sydney', 2),
#  ('climate', 2)]

# %% [markdown]
# ## Search for language in a tweet
#
# Language code is under field 'lang'.
# [Language names](https://developer.twitter.com/en/docs/twitter-for-websites/twitter-for-websites-supported-languages/overview) supported by Twitter will be used to make report.

# %%
langnames = {'ar': 'Arabic', 'bn': 'Bengali', 'cs': 'Czech', 'da': 'Danish', 
             'de': 'German', 'el': 'Greek', 'en': 'English', 'es': 'Spanish',
             'fa': 'Persian', 'fi': 'Finnish', 'fil': 'Filipino', 'fr': 'French',
             'he': 'Hebrew', 'hi': 'Hindi', 'hu': 'Hungarian', 'id': 'Indonesian',
             'it': 'Italian', 'ja': 'Japanese', 'ko': 'Korean', 'msa': 'Malay',
             'nl': 'Dutch', 'no': 'Norwegian', 'pl': 'Polish', 'pt': 'Portuguese',
             'ro': 'Romanian', 'ru': 'Russian', 'sv': 'Swedish', 'th': 'Thai',
             'tr': 'Turkish', 'uk': 'Ukrainian', 'ur': 'Urdu', 'vi': 'Vietnamese',
             'zh-cn': 'Chinese Simplified', 'zh-tw': 'Chinese Traditional'}

def extract_language(tweet):
  """
  Extract language from Tweet Data Dictionary
  """
  
  return tweet.get("lang", "")

langcounts = Counter(map(extract_language, tweets))
print(langcounts)
# Out:
# Counter({'en': 832, 'und': 69, 'fr': 18, 'pt': 17, 'es': 16, 'th': 9, 'tl': 6, 'ar': 4, 'zh': 4, 'de': 4, 'ja': 3, 'in': 2, 'et': 2, 'fa': 2, 'ht': 2, 'ko': 2, 'cy': 1, 'tr': 1, 'nl': 1, 'ro': 1, 'pl': 1, 'hu': 1, 'ru': 1})

# %%
pprint(langcounts.most_common(10))
# Out:
# [('en', 832),
#  ('und', 69),
#  ('fr', 18),
#  ('pt', 17),
#  ('es', 16),
#  ('th', 9),
#  ('tl', 6),
#  ('ar', 4),
#  ('zh', 4),
#  ('de', 4)]

# %% [markdown]
# ## Tweet Processor

# %%
class Tweet:
    """Process line of json text for single tweet data"""

    def __init__(self, text):
      """
      text: line of json text
      """

      self.text = text

      # Tweet data
      text_clean = remove_trails(text)
      self.data = parse_tweet(text_clean)

      # Extract information
      self.hashtags = extract_hashtags(self.data)
      self.lang = extract_language(self.data) # language

tweets_pro = [t for t in map(Tweet, lines) if t.data] # drop badly formatted lines

# Count hashtags, languages
htcounts_pro = Counter()
langcounts_pro = Counter()
for t in tweets_pro:
  htcounts_pro.update(t.hashtags)
  langcounts_pro[t.lang] += 1
print(htcounts_pro)
print(langcounts_pro)
# Out:
# Counter({'climatechange': 6, 'scottyfrommarketing': 6, 'auspol': 6, 'australiaburns': 5, 'sonicmovie': 4, 'bushfiresnsw': 3, 'nswfires': 3, 'sydnye': 2, 'sydney': 2, 'climate': 2, 'happynewyear': 2, 'australianfires': 2, 'fireworks': 2, 'nye2020': 2, 'canberra': 2, 'เป๊กผลิตโชค': 2, 'liarfromtheshire': 2, 'morrisonfires': 2, 'countdown2020withpeck': 2, 'nye': 2, 'configmgr': 1, 'ilovesydney': 1, 'sideproject': 1, 'makers': 1, 'bulltitts': 1, 'fatca': 1, 'decadechallenge': 1, '2010vs2020': 1, 'abc': 1, 'priorities': 1, 'stowaway': 1, 'joseout': 1, 'duindorp': 1, 'gardening': 1, 'urbangardens': 1, 'newyearsday2020': 1, 'smoko': 1, 'youvestolenmychildhood': 1, 'howdareyou': 1, 'peoplearedying': 1, 'coalman': 1, 'brisbane': 1, 'labor': 1, 'loveislandau': 1, 'cheers': 1, 'skål': 1, 'avstwitterpsychic': 1, 'goavsgo': 1, 'climatecriminals': 1, '9news': 1, 'theirabc': 1, 'primeminister': 1, 'sackfomo': 1, 'sackscummo': 1, 'southcoastfires': 1, 'bushfires': 1, 'nswpol': 1, 'peckpalitchoke': 1, 'torvsmin': 1, 'workout': 1, 'aisbangkokcountdown2020xpeck': 1, 'เค้าท์ดาวน์2020กับพี่เป๊ก': 1, 'fe3h': 1, 'sylvix': 1, 'bloodsun': 1, 'energyaccess': 1, 'bringbacktony': 1, 'newyearresolutions': 1, 'เคาท์ดาวน์2020กับพี่เป๊ก': 1, 'my': 1, 'twitter': 1, 'hacked': 1, 'yay': 1, 'freaking': 1, 'nigeria': 1, 'deniers': 1, 'burnnewscorp': 1, 'littlemanmorrison': 1, 'adapt': 1, 'hongkongprotest': 1, 'denierfromtheshire': 1, 'อิจฉาจ้า': 1, 'เศร้า': 1, '500daysofsummer': 1, 'nowplaying': 1, 'scottyfommarketing': 1, 'aliens': 1, 'area51': 1, 'hny2020': 1, 'ausmedia': 1, 'msm': 1, 'victoriafires': 1, 'wankpuffin': 1, 'lockhimup': 1, 'quote': 1, 'tesla': 1, 'israel': 1, 'electriccar': 1, 'australia': 1, 'happynewyear2020': 1, 'bolsonaromaisforteem2020': 1, 'scottludlum': 1, 'koalakiller': 1, 'climateemergency': 1, 'adventure': 1, 'bedaring': 1, 'rbd': 1, 'bilpin': 1, 'riseofskywalker': 1, 'texperkins': 1, 'thefinger': 1})
# Counter({'en': 832, 'und': 69, 'fr': 18, 'pt': 17, 'es': 16, 'th': 9, 'tl': 6, 'ar': 4, 'zh': 4, 'de': 4, 'ja': 3, 'in': 2, 'et': 2, 'fa': 2, 'ht': 2, 'ko': 2, 'cy': 1, 'tr': 1, 'nl': 1, 'ro': 1, 'pl': 1, 'hu': 1, 'ru': 1})

# %% [markdown]
# # Application (process big file)

# %% [markdown]
# ## Read specific chunk

# %%
def read_lines(filename, start=0, end=-1):
  """
  Read specific chunk of filename line by line (lazy)
  filename: json file containing tweet data (big file)
  start: byte position to read from (defaults to start of file)
  end: byte position to read to (defaults to end of file)
  """

  if end < 0:
    end = os.path.getsize(filename)

  with open(filename) as f:
    f.seek(start)
    while f.tell() < end:
      yield f.readline()

# Test
filename = '/tmp/data.txt'
with open(filename, 'w') as fh:
  fh.write("Hello World!\nHow are you today?\nThank you!")
print(*read_lines(filename, end=15), sep="\n")
print(*read_lines(filename, start=15, end=20), sep="\n")
print(*read_lines(filename, start=20), sep="\n")

# Real data
print(*list(read_lines(datafile))[:3], sep="\n") # first 3 lines
# Out:
# Hello World!
#
# How are you today?
#
# w are you today?
#
#  you today?
#
# Thank you!
# {"total_rows":215443567,"offset":211386044,"rows":[
#
# {"id":"1212161512334336000","key":["sydney",2020,1,1],"value":1,"doc":{"_id":"1212161512334336000","_rev":"1-a51c37b5a85cf6a96735628afbea2c75","created_at":"Wed Jan 01 00:00:00 +0000 2020","id":1212161512334336000,"id_str":"1212161512334336000","text":"@La_Doine Pues ahora si, feliz 2020 🎊","truncated":false,"entities":{"hashtags":[],"symbols":[],"user_mentions":[{"screen_name":"La_Doine","name":"Star","id":320174862,"id_str":"320174862","indices":[0,9]}],"urls":[]},"metadata":{"iso_language_code":"es","result_type":"recent"},"source":"<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>","in_reply_to_status_id":1212157896512942000,"in_reply_to_status_id_str":"1212157896512942080","in_reply_to_user_id":320174862,"in_reply_to_user_id_str":"320174862","in_reply_to_screen_name":"La_Doine","user":{"id":1011510954406961200,"id_str":"1011510954406961153","name":"AySeñorQueNosComenLosMonguers","screen_name":"BocataJamonEHM","location":"Calle Wallaby 42 Sidney","description":"Intento de humorista fallido reconvertido en payaso de baja autoestima y gran corazón,no me muero de la pereza que me da.","url":null,"entities":{"description":{"urls":[]}},"protected":false,"followers_count":12245,"friends_count":144,"listed_count":43,"created_at":"Tue Jun 26 07:26:19 +0000 2018","favourites_count":59819,"utc_offset":null,"time_zone":null,"geo_enabled":false,"verified":false,"statuses_count":29587,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"F5F8FA","profile_background_image_url":null,"profile_background_image_url_https":null,"profile_background_tile":false,"profile_image_url":"http://pbs.twimg.com/profile_images/1011512550989721601/nK-Sajra_normal.jpg","profile_image_url_https":"https://pbs.twimg.com/profile_images/1011512550989721601/nK-Sajra_normal.jpg","profile_banner_url":"https://pbs.twimg.com/profile_banners/1011510954406961153/1529998634","profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":true,"default_profile":true,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"none"},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"favorited":false,"retweeted":false,"lang":"es","location":"sydney"}},
#
# {"id":"1212161512770437121","key":["sydney",2020,1,1],"value":1,"doc":{"_id":"1212161512770437121","_rev":"1-1f228a4dc2ba239e787ac0573945aee6","created_at":"Wed Jan 01 00:00:00 +0000 2020","id":1212161512770437000,"id_str":"1212161512770437121","text":"RT @gabriellecj: A prime minister who cannot or will not rise to the occasion - 'No better place to raise kids': Scott Morrison's new year…","truncated":false,"entities":{"hashtags":[],"symbols":[],"user_mentions":[{"screen_name":"gabriellecj","name":"Gabrielle Jackson","id":6814772,"id_str":"6814772","indices":[3,15]}],"urls":[]},"metadata":{"iso_language_code":"en","result_type":"recent"},"source":"<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":169804331,"id_str":"169804331","name":"michael inman","screen_name":"mickinman","location":"Canberra, Australia","description":"In depth producer/reporter. @abccanberra Ex-@canberratimes crime/court reporter","url":"https://t.co/N1HhZ13SSn","entities":{"url":{"urls":[{"url":"https://t.co/N1HhZ13SSn","expanded_url":"http://www.abc.net.au/canberra","display_url":"abc.net.au/canberra","indices":[0,23]}]},"description":{"urls":[]}},"protected":false,"followers_count":2730,"friends_count":5612,"listed_count":63,"created_at":"Fri Jul 23 05:48:59 +0000 2010","favourites_count":867,"utc_offset":null,"time_zone":null,"geo_enabled":false,"verified":true,"statuses_count":12846,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"C0DEED","profile_background_image_url":"http://abs.twimg.com/images/themes/theme1/bg.png","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme1/bg.png","profile_background_tile":true,"profile_image_url":"http://pbs.twimg.com/profile_images/1046381138548150272/sVCsRuDl_normal.jpg","profile_image_url_https":"https://pbs.twimg.com/profile_images/1046381138548150272/sVCsRuDl_normal.jpg","profile_banner_url":"https://pbs.twimg.com/profile_banners/169804331/1469162040","profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":false,"default_profile":false,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"none"},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Tue Dec 31 21:06:57 +0000 2019","id":1212117963165225000,"id_str":"1212117963165224960","text":"A prime minister who cannot or will not rise to the occasion - 'No better place to raise kids': Scott Morrison's ne… https://t.co/pTtEt0vGnv","truncated":true,"entities":{"hashtags":[],"symbols":[],"user_mentions":[],"urls":[{"url":"https://t.co/pTtEt0vGnv","expanded_url":"https://twitter.com/i/web/status/1212117963165224960","display_url":"twitter.com/i/web/status/1…","indices":[117,140]}]},"metadata":{"iso_language_code":"en","result_type":"recent"},"source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":6814772,"id_str":"6814772","name":"Gabrielle Jackson","screen_name":"gabriellecj","location":"Sydney, Australia","description":"Associate news editor for Guardian Australia. My book Pain and Prejudice is out now in Australia & NZ (Allen & Unwin) and UK (Little, Brown). Also in audiobook.","url":"https://t.co/McPGtnaNfX","entities":{"url":{"urls":[{"url":"https://t.co/McPGtnaNfX","expanded_url":"https://www.booktopia.com.au/pain-and-prejudice-gabrielle-jackson/prod9781760529093.html","display_url":"booktopia.com.au/pain-and-preju…" ...

# %% [markdown]
# ## Count hashtags and languages in chunk

# %%
def count_hashtags_langs(filename, start=0, end=-1):
  """
  Count hashtags and languages in specific chunk of filename
  filename: json file containing tweet data (big file)
  start: byte position to read from (defaults to start of file)
  end: byte position to read to (defaults to end of file)
  """
  
  htcounts = Counter()  # hashtag counts
  langcounts = Counter()  # language counts
  nlines = 0  # number of valid lines
  for text in read_lines(filename, start, end):
    tweet = Tweet(text)
    if not tweet.data:  # badly formatted line
      continue
    
    htcounts.update(tweet.hashtags)
    langcounts[tweet.lang] += 1
    nlines += 1

  return htcounts, langcounts, nlines

# Non-splitting
htcounts, langcounts, nlines = count_hashtags_langs(datafile)
print(htcounts)
print(langcounts)
print(nlines)

# Splitting
htcounts1, langcounts1, nlines1 = count_hashtags_langs(datafile, end=1567912)
htcounts2, langcounts2, nlines2 = count_hashtags_langs(datafile, start=1567912, end=3135824)
htcounts3, langcounts3, nlines3 = count_hashtags_langs(datafile, start=3135824)
htcounts_split = htcounts1 + htcounts2 + htcounts3
langcounts_split = langcounts1 + langcounts2 + langcounts3
nlines_split = nlines1 + nlines2 + nlines3
print(htcounts_split)
print(langcounts_split)
print(nlines_split)
# Out:
# Counter({'climatechange': 6, 'scottyfrommarketing': 6, 'auspol': 6, 'australiaburns': 5, 'sonicmovie': 4, 'bushfiresnsw': 3, 'nswfires': 3, 'sydnye': 2, 'sydney': 2, 'climate': 2, 'happynewyear': 2, 'australianfires': 2, 'fireworks': 2, 'nye2020': 2, 'canberra': 2, 'เป๊กผลิตโชค': 2, 'liarfromtheshire': 2, 'morrisonfires': 2, 'countdown2020withpeck': 2, 'nye': 2, 'configmgr': 1, 'ilovesydney': 1, 'sideproject': 1, 'makers': 1, 'bulltitts': 1, 'fatca': 1, 'decadechallenge': 1, '2010vs2020': 1, 'abc': 1, 'priorities': 1, 'stowaway': 1, 'joseout': 1, 'duindorp': 1, 'gardening': 1, 'urbangardens': 1, 'newyearsday2020': 1, 'smoko': 1, 'youvestolenmychildhood': 1, 'howdareyou': 1, 'peoplearedying': 1, 'coalman': 1, 'brisbane': 1, 'labor': 1, 'loveislandau': 1, 'cheers': 1, 'skål': 1, 'avstwitterpsychic': 1, 'goavsgo': 1, 'climatecriminals': 1, '9news': 1, 'theirabc': 1, 'primeminister': 1, 'sackfomo': 1, 'sackscummo': 1, 'southcoastfires': 1, 'bushfires': 1, 'nswpol': 1, 'peckpalitchoke': 1, 'torvsmin': 1, 'workout': 1, 'aisbangkokcountdown2020xpeck': 1, 'เค้าท์ดาวน์2020กับพี่เป๊ก': 1, 'fe3h': 1, 'sylvix': 1, 'bloodsun': 1, 'energyaccess': 1, 'bringbacktony': 1, 'newyearresolutions': 1, 'เคาท์ดาวน์2020กับพี่เป๊ก': 1, 'my': 1, 'twitter': 1, 'hacked': 1, 'yay': 1, 'freaking': 1, 'nigeria': 1, 'deniers': 1, 'burnnewscorp': 1, 'littlemanmorrison': 1, 'adapt': 1, 'hongkongprotest': 1, 'denierfromtheshire': 1, 'อิจฉาจ้า': 1, 'เศร้า': 1, '500daysofsummer': 1, 'nowplaying': 1, 'scottyfommarketing': 1, 'aliens': 1, 'area51': 1, 'hny2020': 1, 'ausmedia': 1, 'msm': 1, 'victoriafires': 1, 'wankpuffin': 1, 'lockhimup': 1, 'quote': 1, 'tesla': 1, 'israel': 1, 'electriccar': 1, 'australia': 1, 'happynewyear2020': 1, 'bolsonaromaisforteem2020': 1, 'scottludlum': 1, 'koalakiller': 1, 'climateemergency': 1, 'adventure': 1, 'bedaring': 1, 'rbd': 1, 'bilpin': 1, 'riseofskywalker': 1, 'texperkins': 1, 'thefinger': 1})
# Counter({'en': 832, 'und': 69, 'fr': 18, 'pt': 17, 'es': 16, 'th': 9, 'tl': 6, 'ar': 4, 'zh': 4, 'de': 4, 'ja': 3, 'in': 2, 'et': 2, 'fa': 2, 'ht': 2, 'ko': 2, 'cy': 1, 'tr': 1, 'nl': 1, 'ro': 1, 'pl': 1, 'hu': 1, 'ru': 1})
# 999
# Counter({'climatechange': 6, 'scottyfrommarketing': 6, 'auspol': 6, 'australiaburns': 5, 'sonicmovie': 4, 'bushfiresnsw': 3, 'nswfires': 3, 'sydnye': 2, 'sydney': 2, 'climate': 2, 'happynewyear': 2, 'australianfires': 2, 'fireworks': 2, 'nye2020': 2, 'canberra': 2, 'เป๊กผลิตโชค': 2, 'liarfromtheshire': 2, 'morrisonfires': 2, 'countdown2020withpeck': 2, 'nye': 2, 'configmgr': 1, 'ilovesydney': 1, 'sideproject': 1, 'makers': 1, 'bulltitts': 1, 'fatca': 1, 'decadechallenge': 1, '2010vs2020': 1, 'abc': 1, 'priorities': 1, 'stowaway': 1, 'joseout': 1, 'duindorp': 1, 'gardening': 1, 'urbangardens': 1, 'newyearsday2020': 1, 'smoko': 1, 'youvestolenmychildhood': 1, 'howdareyou': 1, 'peoplearedying': 1, 'coalman': 1, 'brisbane': 1, 'labor': 1, 'loveislandau': 1, 'cheers': 1, 'skål': 1, 'avstwitterpsychic': 1, 'goavsgo': 1, 'climatecriminals': 1, '9news': 1, 'theirabc': 1, 'primeminister': 1, 'sackfomo': 1, 'sackscummo': 1, 'southcoastfires': 1, 'bushfires': 1, 'nswpol': 1, 'peckpalitchoke': 1, 'torvsmin': 1, 'workout': 1, 'aisbangkokcountdown2020xpeck': 1, 'เค้าท์ดาวน์2020กับพี่เป๊ก': 1, 'fe3h': 1, 'sylvix': 1, 'bloodsun': 1, 'energyaccess': 1, 'bringbacktony': 1, 'newyearresolutions': 1, 'เคาท์ดาวน์2020กับพี่เป๊ก': 1, 'my': 1, 'twitter': 1, 'hacked': 1, 'yay': 1, 'freaking': 1, 'nigeria': 1, 'deniers': 1, 'burnnewscorp': 1, 'littlemanmorrison': 1, 'adapt': 1, 'hongkongprotest': 1, 'denierfromtheshire': 1, 'อิจฉาจ้า': 1, 'เศร้า': 1, '500daysofsummer': 1, 'nowplaying': 1, 'scottyfommarketing': 1, 'aliens': 1, 'area51': 1, 'hny2020': 1, 'ausmedia': 1, 'msm': 1, 'victoriafires': 1, 'wankpuffin': 1, 'lockhimup': 1, 'quote': 1, 'tesla': 1, 'israel': 1, 'electriccar': 1, 'australia': 1, 'happynewyear2020': 1, 'bolsonaromaisforteem2020': 1, 'scottludlum': 1, 'koalakiller': 1, 'climateemergency': 1, 'adventure': 1, 'bedaring': 1, 'rbd': 1, 'bilpin': 1, 'riseofskywalker': 1, 'texperkins': 1, 'thefinger': 1})
# Counter({'en': 832, 'und': 69, 'fr': 18, 'pt': 17, 'es': 16, 'th': 9, 'tl': 6, 'ar': 4, 'zh': 4, 'de': 4, 'ja': 3, 'in': 2, 'et': 2, 'fa': 2, 'ht': 2, 'ko': 2, 'cy': 1, 'tr': 1, 'nl': 1, 'ro': 1, 'pl': 1, 'hu': 1, 'ru': 1})
# 999

# %% [markdown]
# ## Process chunk

# %%
def process_chunk(filename, chunks, number):
  """
  Pick and process equal-size chunk of filename according to its number
  filename: json file containing tweet data (big file)
  chunks: total number of chunks
  number (starting 0): current chunk number
  """

  size = os.path.getsize(datafile)
  start = int(number / chunks * size) # start byte position
  end = int((number+1) / chunks * size) # end byte position
  htcounts, langcounts, nlines = count_hashtags_langs(filename, start, end)

  return htcounts, langcounts, nlines

# Split chunks
htcounts1, langcounts1, nlines1 = process_chunk(datafile, 3, 0)
htcounts2, langcounts2, nlines2 = process_chunk(datafile, 3, 1)
htcounts3, langcounts3, nlines3 = process_chunk(datafile, 3, 2)
htcounts_split = htcounts1 + htcounts2 + htcounts3
langcounts_split = langcounts1 + langcounts2 + langcounts3
nlines_split = nlines1 + nlines2 + nlines3
print(htcounts_split)
print(langcounts_split)
print(nlines_split)
# Out:
# Counter({'climatechange': 6, 'scottyfrommarketing': 6, 'auspol': 6, 'australiaburns': 5, 'sonicmovie': 4, 'bushfiresnsw': 3, 'nswfires': 3, 'sydnye': 2, 'sydney': 2, 'climate': 2, 'happynewyear': 2, 'australianfires': 2, 'fireworks': 2, 'nye2020': 2, 'canberra': 2, 'เป๊กผลิตโชค': 2, 'liarfromtheshire': 2, 'morrisonfires': 2, 'countdown2020withpeck': 2, 'nye': 2, 'configmgr': 1, 'ilovesydney': 1, 'sideproject': 1, 'makers': 1, 'bulltitts': 1, 'fatca': 1, 'decadechallenge': 1, '2010vs2020': 1, 'abc': 1, 'priorities': 1, 'stowaway': 1, 'joseout': 1, 'duindorp': 1, 'gardening': 1, 'urbangardens': 1, 'newyearsday2020': 1, 'smoko': 1, 'youvestolenmychildhood': 1, 'howdareyou': 1, 'peoplearedying': 1, 'coalman': 1, 'brisbane': 1, 'labor': 1, 'loveislandau': 1, 'cheers': 1, 'skål': 1, 'avstwitterpsychic': 1, 'goavsgo': 1, 'climatecriminals': 1, '9news': 1, 'theirabc': 1, 'primeminister': 1, 'sackfomo': 1, 'sackscummo': 1, 'southcoastfires': 1, 'bushfires': 1, 'nswpol': 1, 'peckpalitchoke': 1, 'torvsmin': 1, 'workout': 1, 'aisbangkokcountdown2020xpeck': 1, 'เค้าท์ดาวน์2020กับพี่เป๊ก': 1, 'fe3h': 1, 'sylvix': 1, 'bloodsun': 1, 'energyaccess': 1, 'bringbacktony': 1, 'newyearresolutions': 1, 'เคาท์ดาวน์2020กับพี่เป๊ก': 1, 'my': 1, 'twitter': 1, 'hacked': 1, 'yay': 1, 'freaking': 1, 'nigeria': 1, 'deniers': 1, 'burnnewscorp': 1, 'littlemanmorrison': 1, 'adapt': 1, 'hongkongprotest': 1, 'denierfromtheshire': 1, 'อิจฉาจ้า': 1, 'เศร้า': 1, '500daysofsummer': 1, 'nowplaying': 1, 'scottyfommarketing': 1, 'aliens': 1, 'area51': 1, 'hny2020': 1, 'ausmedia': 1, 'msm': 1, 'victoriafires': 1, 'wankpuffin': 1, 'lockhimup': 1, 'quote': 1, 'tesla': 1, 'israel': 1, 'electriccar': 1, 'australia': 1, 'happynewyear2020': 1, 'bolsonaromaisforteem2020': 1, 'scottludlum': 1, 'koalakiller': 1, 'climateemergency': 1, 'adventure': 1, 'bedaring': 1, 'rbd': 1, 'bilpin': 1, 'riseofskywalker': 1, 'texperkins': 1, 'thefinger': 1})
# Counter({'en': 832, 'und': 69, 'fr': 18, 'pt': 17, 'es': 16, 'th': 9, 'tl': 6, 'ar': 4, 'zh': 4, 'de': 4, 'ja': 3, 'in': 2, 'et': 2, 'fa': 2, 'ht': 2, 'ko': 2, 'cy': 1, 'tr': 1, 'nl': 1, 'ro': 1, 'pl': 1, 'hu': 1, 'ru': 1})
# 999

# %% [markdown]
# ## Sum respective counts from all chunks and find overall top 10s

# %%
N = 3 # number of chunks

def main():
  htcounts_all = Counter()  # overall hashtag counts
  langcounts_all = Counter()  # overall language counts
  nlines_all = 0  # overall number of lines
  for i in range(N):  # for each chunk number
    htcounts, langcounts, nlines = process_chunk(datafile, N, i)
    htcounts_all += htcounts
    langcounts_all += langcounts
    nlines_all += nlines
  print(htcounts_all)
  print(langcounts_all)
  print(nlines_all)
  pprint(htcounts_all.most_common(10))
  pprint(langcounts_all.most_common(10))

main()
# Out:
# Counter({'climatechange': 6, 'scottyfrommarketing': 6, 'auspol': 6, 'australiaburns': 5, 'sonicmovie': 4, 'bushfiresnsw': 3, 'nswfires': 3, 'sydnye': 2, 'sydney': 2, 'climate': 2, 'happynewyear': 2, 'australianfires': 2, 'fireworks': 2, 'nye2020': 2, 'canberra': 2, 'เป๊กผลิตโชค': 2, 'liarfromtheshire': 2, 'morrisonfires': 2, 'countdown2020withpeck': 2, 'nye': 2, 'configmgr': 1, 'ilovesydney': 1, 'sideproject': 1, 'makers': 1, 'bulltitts': 1, 'fatca': 1, 'decadechallenge': 1, '2010vs2020': 1, 'abc': 1, 'priorities': 1, 'stowaway': 1, 'joseout': 1, 'duindorp': 1, 'gardening': 1, 'urbangardens': 1, 'newyearsday2020': 1, 'smoko': 1, 'youvestolenmychildhood': 1, 'howdareyou': 1, 'peoplearedying': 1, 'coalman': 1, 'brisbane': 1, 'labor': 1, 'loveislandau': 1, 'cheers': 1, 'skål': 1, 'avstwitterpsychic': 1, 'goavsgo': 1, 'climatecriminals': 1, '9news': 1, 'theirabc': 1, 'primeminister': 1, 'sackfomo': 1, 'sackscummo': 1, 'southcoastfires': 1, 'bushfires': 1, 'nswpol': 1, 'peckpalitchoke': 1, 'torvsmin': 1, 'workout': 1, 'aisbangkokcountdown2020xpeck': 1, 'เค้าท์ดาวน์2020กับพี่เป๊ก': 1, 'fe3h': 1, 'sylvix': 1, 'bloodsun': 1, 'energyaccess': 1, 'bringbacktony': 1, 'newyearresolutions': 1, 'เคาท์ดาวน์2020กับพี่เป๊ก': 1, 'my': 1, 'twitter': 1, 'hacked': 1, 'yay': 1, 'freaking': 1, 'nigeria': 1, 'deniers': 1, 'burnnewscorp': 1, 'littlemanmorrison': 1, 'adapt': 1, 'hongkongprotest': 1, 'denierfromtheshire': 1, 'อิจฉาจ้า': 1, 'เศร้า': 1, '500daysofsummer': 1, 'nowplaying': 1, 'scottyfommarketing': 1, 'aliens': 1, 'area51': 1, 'hny2020': 1, 'ausmedia': 1, 'msm': 1, 'victoriafires': 1, 'wankpuffin': 1, 'lockhimup': 1, 'quote': 1, 'tesla': 1, 'israel': 1, 'electriccar': 1, 'australia': 1, 'happynewyear2020': 1, 'bolsonaromaisforteem2020': 1, 'scottludlum': 1, 'koalakiller': 1, 'climateemergency': 1, 'adventure': 1, 'bedaring': 1, 'rbd': 1, 'bilpin': 1, 'riseofskywalker': 1, 'texperkins': 1, 'thefinger': 1})
# Counter({'en': 832, 'und': 69, 'fr': 18, 'pt': 17, 'es': 16, 'th': 9, 'tl': 6, 'ar': 4, 'zh': 4, 'de': 4, 'ja': 3, 'in': 2, 'et': 2, 'fa': 2, 'ht': 2, 'ko': 2, 'cy': 1, 'tr': 1, 'nl': 1, 'ro': 1, 'pl': 1, 'hu': 1, 'ru': 1})
# 999
# [('climatechange', 6),
#  ('scottyfrommarketing', 6),
#  ('auspol', 6),
#  ('australiaburns', 5),
#  ('sonicmovie', 4),
#  ('bushfiresnsw', 3),
#  ('nswfires', 3),
#  ('sydnye', 2),
#  ('sydney', 2),
#  ('climate', 2)]
# [('en', 832),
#  ('und', 69),
#  ('fr', 18),
#  ('pt', 17),
#  ('es', 16),
#  ('th', 9),
#  ('tl', 6),
#  ('ar', 4),
#  ('zh', 4),
#  ('de', 4)]

# %%
import regex

text = "can't, Å, é, and #中ABC _ #sh_t! #abc #มาพ่องเพิ่งอะไร"
print(regex.findall('#\w+', text))
# Out:
# ['#中ABC', '#sh_t', '#abc', '#มาพ่องเพิ่งอะไร']

# %% [markdown]
# # Run application

# %%
# !mpirun --allow-run-as-root -np 4 python3 __main__.py {datafile}
# Out:
# Traceback (most recent call last):
#   File "__main__.py", line 1, in <module>
#     from mpi4py import MPI
# ModuleNotFoundError: No module named 'mpi4py'
# -------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code.. Per user-direction, the job has been aborted.
# -------------------------------------------------------
# Traceback (most recent call last):
#   File "__main__.py", line 1, in <module>
#     from mpi4py import MPI
# ModuleNotFoundError: No module named 'mpi4py'
# --------------------------------------------------------------------------
# mpirun detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#
#   Process name: [[36536,1],0]
#   Exit code:    1
# --------------------------------------------------------------------------

# %%
a = Counter(dict([('climatechange', 6),
 ('scottyfrommarketing', 6),
 ('auspol', 6),
 ('australiaburns', 5),
 ('sonicmovie', 4),
 ('bushfiresnsw', 3),
 ('nswfires', 3),
 ('sydnye', 2),
 ('sydney', 2),
 ('climate', 2)]))
b = a.most_common()
a.most_common(None)
print(*(f"{i+1}. {tag}, {count}" for i, (tag, count) in enumerate(b)))

list(enumerate(a))
# Out:
# Counter({'climatechange': 6, 'scottyfrommarketing': 6, 'auspol': 6, 'australiaburns': 5, 'sonicmovie': 4, 'bushfiresnsw': 3, 'nswfires': 3, 'sydnye': 2, 'sydney': 2, 'climate': 2})
